# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpt
import seaborn as sns

dat = pd.read_csv(r"C:\Users\Ted\Desktop\6300\as_2\housing.csv")
housing = pd.DataFrame(dat)
housing.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
plt.figure(figsize=(20, 15))
fig, axs = plt.subplots(ncols=3)

sns.distplot(housing['latitude'],bins=50,kde=False,ax=axs[0])
sns.distplot(housing['longitude'],bins=50,kde=False,ax=axs[1])
sns.distplot(housing['median_income'],bins=50,kde=False,ax=axs[2])
#sns.distplot(housing['house_median_age'],bins=50,kde=False,ax=axs[2])

fig, axs2 = plt.subplots(ncols=3)

sns.distplot(housing['total_rooms'],bins=50,kde=False,ax=axs2[0])
sns.distplot(housing['population'],bins=50,kde=False,ax=axs2[1])
sns.distplot(housing['median_house_value'],bins=50,kde=False,ax=axs2[2])

# %%
plt.hist(housing['latitude'], normed=True, bins=50)
plt.ylabel('Probability')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
plt.figure(figsize=(20, 15))

# We can set the number of bins with the `bins` kwarg
axs[0].hist(housing['latitude'], normed = True, bins = 50)
df1 = housing['latitude']
axs[1].hist(housing['longitude'], normed = True, bins = 50)
axs[2].hist(housing['median_income'], normed = True, bins = 50)

fig, axs2 = plt.subplots(1, 3, sharey=True)
plt.figure(figsize=(20, 15))
# We can set the number of bins with the `bins` kwarg
axs2[0].hist(housing['total_rooms'], normed = True, bins = 50)
axs2[1].hist(housing['population'], normed = True, bins = 50)
axs2[2].hist(housing['median_house_value'], normed = True, bins = 50)

fig, axs3 = plt.subplots(1, 3, sharey=True)
plt.figure(figsize=(20, 15))
# We can set the number of bins with the `bins` kwarg
axs3[0].hist(housing['housing_median_age'], normed = True, bins = 50)
axs3[1].hist(housing['households'], normed = True, bins = 50)
A = np.array(housing['total_bedrooms'])
axs3[2].hist(A[~np.isnan(A)],normed = True, bins = 50)
#axs3[2].hist(housing['median_house_value'], normed = True, bins = 50)





plt.show()

# %%
import numpy as np


#plt.hist(df, normed=True, bins=50)
#plt.ylabel('Probability')
#plt.show()

A = np.array(housing['total_bedrooms'])
plt.hist(A[~np.isnan(A)])
plt.show()

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=200000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)

# %%
x1 = list(housing['median_income'])
x2 = list(housing['median_house_value'])

colors = ['#E69F00', '#56B4E9']
names = ['median_income','median_house_value']

plt.hist([x1, x2], bins = 15,color = colors,normed=True, label=names)
# Out:
# ([array([2.999997e-05, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#          0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#          0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#          0.000000e+00, 0.000000e+00, 0.000000e+00]),
#   array([3.19767122e-08, 1.49418455e-06, 3.79069388e-06, 3.62208940e-06,
#          4.53487919e-06, 3.86772869e-06, 2.95639239e-06, 2.31831163e-06,
#          1.80813773e-06, 1.12790585e-06, 1.19476625e-06, 7.18022538e-07,
#          4.66569301e-07, 3.92441468e-07, 1.67587042e-06])],
#  array([4.99900000e-01, 3.33338666e+04, 6.66672332e+04, 1.00000600e+05,
#         1.33333967e+05, 1.66667333e+05, 2.00000700e+05, 2.33334067e+05,
#         2.66667433e+05, 3.00000800e+05, 3.33334167e+05, 3.66667533e+05,
#         4.00000900e+05, 4.33334267e+05, 4.66667633e+05, 5.00001000e+05]),
#  <a list of 2 Lists of Patches objects>)

# %%
v1 = pd.DataFrame(housing, columns=['median_income'])
v2 = pd.DataFrame(housing, columns=['median_house_value'])

# %%
type(v2)
# Out:
# pandas.core.frame.DataFrame

# %%
v1.head()
# Out:
#    median_income
# 0         8.3252
# 1         8.3014
# 2         7.2574
# 3         5.6431
# 4         3.8462

# %%
import numpy as np
import pandas as pd

# %%
v2 = v2.values

# %%
v1 = v1.values

# %%
type(v2)
# Out:
# numpy.ndarray

# %%
bins = np.linspace(-10, 10, 100)

# %%
import matplotlib.pyplot as plt

plt.hist(v1, bins, alpha=0.5,normed=True, label='x')
plt.hist(v2, bins, alpha=0.5,normed=True, label='y')

plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\numpy\lib\histograms.py:893: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
import random
import numpy
from matplotlib import pyplot

x = [random.gauss(3,1) for _ in range(400)]
y = [random.gauss(4,2) for _ in range(400)]

bins = numpy.linspace(-10, 10, 100)

pyplot.hist(x, bins, alpha=0.5, label='x')
pyplot.hist(y, bins, alpha=0.5, label='y')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
sns.distplot(housing['median_income'],norm_hist=False, bins=20, hist = True, kde = True)
sns.distplot(housing['median_house_value'],norm_hist=False, bins=20, hist = True, kde = True)
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap


x = housing['latitude']
y = housing['longitude']

plt.scatter(x, y, cmap='viridis')
plt.show()

# %%
import seaborn as sns

pop = housing['population']
#sns.scatterplot(x="latitude", y="longitude",hue="median_house_value", data=housing,s=pop/50)

plt.show()


housing.plot(kind="scatter", x="longitude", y="latitude",
    s=pop/50, label="median_house_value",
    c="median_house_value", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.5, figsize=(10,8),
)
plt.legend()
plt.show()
